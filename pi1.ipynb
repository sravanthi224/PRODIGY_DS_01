# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading the Dataset

# %%
df=pd.read_csv("population.csv")

# %%
df.head()
# Out:
#    CensusTract    State   County  TotalPop   Men  Women  Hispanic  White  \
# 0   1001020100  Alabama  Autauga      1948   940   1008       0.9   87.4
# 1   1001020200  Alabama  Autauga      2156  1059   1097       0.8   40.4
# 2   1001020300  Alabama  Autauga      2968  1364   1604       0.0   74.5
# 3   1001020400  Alabama  Autauga      4423  2172   2251      10.5   82.8
# 4   1001020500  Alabama  Autauga     10763  4922   5841       0.7   68.5
#
#    Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0    7.7     0.3  ...   0.5          2.3         2.1         25.0       943
# 1   53.3     0.0  ...   0.0          0.7         0.0         23.4       753
# 2   18.6     0.5  ...   0.0          0.0         2.5         19.6      1373
# 3    3.7     1.6  ...   0.0          2.6         1.6         25.3      1782
# 4   24.8     0.0  ...   0.0          0.6         0.9         24.8      5037
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# ...

# %% [markdown]
# # Bar Chart

# %%
state_counts = df['State'].value_counts().sort_index()
print(state_counts)
# Out:
# State
# Alabama                 1181
# Alaska                   167
# Arizona                 1526
# Arkansas                 686
# California              8057
# Colorado                1249
# Connecticut              833
# Delaware                 218
# District of Columbia     179
# Florida                 4245
# Georgia                 1969
# Hawaii                   351
# Idaho                    298
# Illinois                3123
# Indiana                 1511
# Iowa                     825
# Kansas                   770
# Kentucky                1115
# Louisiana               1148
# Maine                    358
# Maryland                1406
# Massachusetts           1478
# Michigan                2813
# Minnesota               1338
# Mississippi              664
# Missouri                1393
# Montana                  271
# Nebraska                 532
# Nevada                   687
# New Hampshire            295
# New Jersey              2010
# New Mexico               499
# ...

# %%
plt.figure(figsize=(12, 6))
plt.bar(state_counts.index, state_counts.values, color='skyblue')
plt.title('Distribution of States')
plt.xlabel('State')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# Selecting the columns for the bar chart
County = df['County']
total_population = df['TotalPop']

# %%
# Creating the bar chart
plt.figure(figsize=(10, 6))
plt.bar(County, total_population, color='skyblue')
plt.title('Total Population by County in Autauga County, Alabama')
plt.xlabel('County')
plt.ylabel('Total Population')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Histogram

# %%
# Selecting the column for the histogram
mean_commute_times = df['MeanCommute']

# %%
# Creating the histogram
plt.figure(figsize=(10, 6))
plt.hist(mean_commute_times, bins=5, color='skyblue', edgecolor='black')

# Adding title and labels
plt.title('Distribution of Mean Commute Times in Autauga County, Alabama')
plt.xlabel('Mean Commute Time (minutes)')
plt.ylabel('Frequency')

# Display the histogram
plt.tight_layout()
plt.show()

# %% [markdown]
# # Bar Chart For Gender

# %%
# Extracting the total population of men and women for the bar chart
genders = ['Men', 'Women']
gender_counts = [df['Men'].sum(), df['Women'].sum()]

# %%
# Creating the bar chart for gender distribution
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.bar(genders, gender_counts, color=['blue', 'pink'])
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Total Population')
# Out:
# Text(0, 0.5, 'Total Population')
